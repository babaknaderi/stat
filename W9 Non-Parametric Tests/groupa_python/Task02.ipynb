# %% [markdown]
# # 09 Non-Parametric Tests - Task 2

# %% [markdown]
# Does the testStimulus (independent variable) have a significant influence on
# speech quality ratings (dependent variable)? If yes, for which cases?
#
# Please assume that each of the six files was assessed by a different set of test participants and only use the ratings of the first repetition.
# Use the quality ratings provided in the dataset “speech_quality_repetition_dataset”.

# %%
import numpy as np
import pandas as pd
import scipy

# !pip install pingouin
import pingouin as pg

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", context="talk")
cm = sns.diverging_palette(127, 14, s=99, l=55, as_cmap=True)

FIGSIZE = (20,4)

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv("../datasets/DB03_speech_quality_repetition_dataset.csv")

mask = (df['repetition'] == 1)
df = df.loc[mask]
print(df.testStimulus.unique())

df
# Out:
# ['haus_m_700_bpf_200_2800_normAsl_-26' 'haus_m_700_mnru_Q_14_normAsl_-26'
#  'haus_m_700_normAsl_-26' 'maus_m_700_bpf_200_2800_normAsl_-26'
#  'maus_m_700_mnru_Q_14_normAsl_-26' 'maus_m_700_normAsl_-26']
#     subjectCode                         testStimulus  repetition  rating
# 0          vp01  haus_m_700_bpf_200_2800_normAsl_-26           1       2
# 4          vp02  haus_m_700_bpf_200_2800_normAsl_-26           1       2
# 8          vp03  haus_m_700_bpf_200_2800_normAsl_-26           1       3
# 12         vp04  haus_m_700_bpf_200_2800_normAsl_-26           1       3
# 16         vp05  haus_m_700_bpf_200_2800_normAsl_-26           1       2
# ..          ...                                  ...         ...     ...
# 868        vp33               maus_m_700_normAsl_-26           1       4
# 872        vp34               maus_m_700_normAsl_-26           1       5
# 876        vp35               maus_m_700_normAsl_-26           1       5
# 880        vp36               maus_m_700_normAsl_-26           1       5
# 884        vp37               maus_m_700_normAsl_-26           1       5
#
# [222 rows x 4 columns]

# %% [markdown]
# ## Non-parametric Tests
# ![flowchart_nonparametric](https://pingouin-stats.org/_images/flowchart_nonparametric.svg)
# Source: https://pingouin-stats.org/guidelines.html#id7

# %% [markdown]
# ### Kruskal-Wallis-Test

# %%
df.groupby("testStimulus").ngroups
# Out:
# 6

# %%
result = pg.kruskal(df, dv="rating", between="testStimulus")
result.style.background_gradient(cmap=cm, subset=["p-unc"])
# Out:
# <style  type="text/css" >
#     #T_83a49180_4c42_11ea_8e86_aa0000b0ab3arow0_col3 {
#             background-color:  #169906;
#             color:  #000000;
#         }</style><table id="T_83a49180_4c42_11ea_8e86_aa0000b0ab3a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Source</th>        <th class="col_heading level0 col1" >ddof1</th>        <th class="col_heading level0 col2" >H</th>        <th class="col_heading level0 col3" >p-unc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83a49180_4c42_11ea_8e86_aa0000b0ab3alevel0_row0" class="row_heading level0 row0" >Kruskal</th>
#                         <td id="T_83a49180_4c42_11ea_8e86_aa0000b0ab3arow0_col0" class="data row0 col0" >testStimulus</td>
#                         <td id="T_83a49180_4c42_11ea_8e86_aa0000b0ab3arow0_col1" class="data row0 col1" >5</td>
#                         <td id="T_83a49180_4c42_11ea_8e86_aa0000b0ab3arow0_col2" class="data row0 col2" >130.897000</td>
#                         <td id="T_83a49180_4c42_11ea_8e86_aa0000b0ab3arow0_col3" class="data row0 col3" >0.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - `H` : The Kruskal-Wallis H statistic, corrected for ties
# - `p-unc` : Uncorrected p-value
# - `dof` : degrees of freedom
#
# Source: https://pingouin-stats.org/generated/pingouin.kruskal.html

# %%
result = pg.pairwise_ttests(df, dv="rating", between="testStimulus", parametric=False, padjust='bonf')
result.style.background_gradient(cmap=cm, subset=["p-corr"])
# Out:
# <style  type="text/css" >
#     #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col8 {
#             background-color:  #fe2d07;
#             color:  #f1f1f1;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col8 {
#             background-color:  #fe2d07;
#             color:  #f1f1f1;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow3_col8 {
#             background-color:  #51b545;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow4_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow5_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow6_col8 {
#             background-color:  #fe8069;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow7_col8 {
#             background-color:  #fe2d07;
#             color:  #f1f1f1;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow8_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow9_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow10_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow11_col8 {
#             background-color:  #fe2d07;
#             color:  #f1f1f1;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow12_col8 {
#             background-color:  #29a21b;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow13_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }    #T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow14_col8 {
#             background-color:  #169906;
#             color:  #000000;
#         }</style><table id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Contrast</th>        <th class="col_heading level0 col1" >A</th>        <th class="col_heading level0 col2" >B</th>        <th class="col_heading level0 col3" >Paired</th>        <th class="col_heading level0 col4" >Parametric</th>        <th class="col_heading level0 col5" >U-val</th>        <th class="col_heading level0 col6" >Tail</th>        <th class="col_heading level0 col7" >p-unc</th>        <th class="col_heading level0 col8" >p-corr</th>        <th class="col_heading level0 col9" >p-adjust</th>        <th class="col_heading level0 col10" >hedges</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col0" class="data row0 col0" >testStimulus</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col1" class="data row0 col1" >haus_m_700_bpf_200_2800_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col2" class="data row0 col2" >haus_m_700_mnru_Q_14_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col3" class="data row0 col3" >False</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col4" class="data row0 col4" >False</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col5" class="data row0 col5" >827.500000</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col6" class="data row0 col6" >two-sided</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col7" class="data row0 col7" >0.101691</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col8" class="data row0 col8" >1.000000</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col9" class="data row0 col9" >bonf</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow0_col10" class="data row0 col10" >0.375000</td>
#             </tr>
#             <tr>
#                         <th id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col0" class="data row1 col0" >testStimulus</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col1" class="data row1 col1" >haus_m_700_bpf_200_2800_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col2" class="data row1 col2" >haus_m_700_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col3" class="data row1 col3" >False</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col4" class="data row1 col4" >False</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col5" class="data row1 col5" >88.500000</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col6" class="data row1 col6" >two-sided</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col7" class="data row1 col7" >0.000000</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col8" class="data row1 col8" >0.000000</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col9" class="data row1 col9" >bonf</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow1_col10" class="data row1 col10" >-2.344000</td>
#             </tr>
#             <tr>
#                         <th id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col0" class="data row2 col0" >testStimulus</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col1" class="data row2 col1" >haus_m_700_bpf_200_2800_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col2" class="data row2 col2" >maus_m_700_bpf_200_2800_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col3" class="data row2 col3" >False</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col4" class="data row2 col4" >False</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col5" class="data row2 col5" >667.500000</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col6" class="data row2 col6" >two-sided</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col7" class="data row2 col7" >0.849032</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col8" class="data row2 col8" >1.000000</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col9" class="data row2 col9" >bonf</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow2_col10" class="data row2 col10" >-0.056000</td>
#             </tr>
#             <tr>
#                         <th id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow3_col0" class="data row3 col0" >testStimulus</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow3_col1" class="data row3 col1" >haus_m_700_bpf_200_2800_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow3_col2" class="data row3 col2" >maus_m_700_mnru_Q_14_normAsl_-26</td>
#                         <td id="T_83b7e7c6_4c42_11ea_8e86_aa0000b0ab3arow3_col3" class="data row3 col3" >False</td>

# %% [markdown]
# - `A` : Name of first measurement
# - `B` : Name of second measurement
# - `Paired` : indicates whether the two measurements are paired or not
# - `Parametric` : indicates if (non)-parametric tests were used
# - `Tail` : indicate whether the p-values are one-sided or two-sided
# - `T` : T statistic (only if parametric=True)
# - `U-val` : Mann-Whitney U stat (if parametric=False and unpaired data)
# - `W-val` : Wilcoxon W stat (if parametric=False and paired data)
# - `p-unc` : Uncorrected p-values
# - `p-corr` : Corrected p-values
# - `p-adjust` : p-values correction method
# - `BF10` : Bayes Factor
# - `hedges` : effect size (or any effect size defined in ``effsize``)
#
# Source: https://pingouin-stats.org/generated/pingouin.pairwise_ttests.html
